# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 887us/sample - loss: 221.9646 - y1_output_loss: 105.1153 - y2_output_loss: 114.8704 - y1_output_root_mean_squared_error: 10.3011 - y2_output_root_mean_squared_error: 10.7635 - val_loss: 40.4028 - val_y1_output_loss: 17.6894 - val_y2_output_loss: 21.6117 - val_y1_output_root_mean_squared_error: 4.2673 - val_y2_output_root_mean_squared_error: 4.7109
# Epoch 2/500
# 614/614 [==============================] - 0s 135us/sample - loss: 30.9167 - y1_output_loss: 12.1347 - y2_output_loss: 18.6000 - y1_output_root_mean_squared_error: 3.4898 - y2_output_root_mean_squared_error: 4.3287 - val_loss: 26.9970 - val_y1_output_loss: 10.9581 - val_y2_output_loss: 15.3427 - val_y1_output_root_mean_squared_error: 3.3642 - val_y2_output_root_mean_squared_error: 3.9597
# Epoch 3/500
# 614/614 [==============================] - 0s 141us/sample - loss: 29.2722 - y1_output_loss: 11.1571 - y2_output_loss: 17.9316 - y1_output_root_mean_squared_error: 3.3494 - y2_output_root_mean_squared_error: 4.2490 - val_loss: 23.7059 - val_y1_output_loss: 9.0272 - val_y2_output_loss: 14.2419 - val_y1_output_root_mean_squared_error: 3.0424 - val_y2_output_root_mean_squared_error: 3.8013
# Epoch 4/500
# 614/614 [==============================] - 0s 128us/sample - loss: 26.4728 - y1_output_loss: 10.0246 - y2_output_loss: 16.6242 - y1_output_root_mean_squared_error: 3.1687 - y2_output_root_mean_squared_error: 4.0537 - val_loss: 25.3490 - val_y1_output_loss: 11.1987 - val_y2_output_loss: 13.6338 - val_y1_output_root_mean_squared_error: 3.3942 - val_y2_output_root_mean_squared_error: 3.7187
# Epoch 5/500
# 614/614 [==============================] - 0s 129us/sample - loss: 24.5707 - y1_output_loss: 9.1603 - y2_output_loss: 15.2215 - y1_output_root_mean_squared_error: 3.0360 - y2_output_root_mean_squared_error: 3.9183 - val_loss: 22.9478 - val_y1_output_loss: 8.5675 - val_y2_output_loss: 13.7993 - val_y1_output_root_mean_squared_error: 2.9771 - val_y2_output_root_mean_squared_error: 3.7530
# Epoch 6/500
# 614/614 [==============================] - 0s 129us/sample - loss: 19.4705 - y1_output_loss: 8.4554 - y2_output_loss: 11.1878 - y1_output_root_mean_squared_error: 2.9067 - y2_output_root_mean_squared_error: 3.3199 - val_loss: 38.1021 - val_y1_output_loss: 9.5795 - val_y2_output_loss: 27.6432 - val_y1_output_root_mean_squared_error: 3.1479 - val_y2_output_root_mean_squared_error: 5.3097
# Epoch 7/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.3123 - y1_output_loss: 8.4985 - y2_output_loss: 12.7819 - y1_output_root_mean_squared_error: 2.9109 - y2_output_root_mean_squared_error: 3.5831 - val_loss: 23.4881 - val_y1_output_loss: 7.6127 - val_y2_output_loss: 15.4787 - val_y1_output_root_mean_squared_error: 2.8040 - val_y2_output_root_mean_squared_error: 3.9530
# Epoch 8/500
# 614/614 [==============================] - 0s 128us/sample - loss: 20.7538 - y1_output_loss: 8.0907 - y2_output_loss: 12.6419 - y1_output_root_mean_squared_error: 2.8451 - y2_output_root_mean_squared_error: 3.5579 - val_loss: 35.6682 - val_y1_output_loss: 11.1049 - val_y2_output_loss: 23.9309 - val_y1_output_root_mean_squared_error: 3.3806 - val_y2_output_root_mean_squared_error: 4.9234
# Epoch 9/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.6829 - y1_output_loss: 7.9581 - y2_output_loss: 13.5493 - y1_output_root_mean_squared_error: 2.8333 - y2_output_root_mean_squared_error: 3.6953 - val_loss: 19.5056 - val_y1_output_loss: 7.4275 - val_y2_output_loss: 11.6488 - val_y1_output_root_mean_squared_error: 2.7682 - val_y2_output_root_mean_squared_error: 3.4413
# Epoch 10/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.0417 - y1_output_loss: 8.0739 - y2_output_loss: 12.8204 - y1_output_root_mean_squared_error: 2.8523 - y2_output_root_mean_squared_error: 3.5925 - val_loss: 19.7502 - val_y1_output_loss: 7.3019 - val_y2_output_loss: 11.9555 - val_y1_output_root_mean_squared_error: 2.7478 - val_y2_output_root_mean_squared_error: 3.4928
# Epoch 11/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.3508 - y1_output_loss: 8.2112 - y2_output_loss: 13.2575 - y1_output_root_mean_squared_error: 2.8415 - y2_output_root_mean_squared_error: 3.6437 - val_loss: 18.4931 - val_y1_output_loss: 6.8084 - val_y2_output_loss: 11.2706 - val_y1_output_root_mean_squared_error: 2.6486 - val_y2_output_root_mean_squared_error: 3.3879
# Epoch 12/500
# 614/614 [==============================] - 0s 130us/sample - loss: 19.2497 - y1_output_loss: 7.4852 - y2_output_loss: 11.7178 - y1_output_root_mean_squared_error: 2.7282 - y2_output_root_mean_squared_error: 3.4361 - val_loss: 19.1084 - val_y1_output_loss: 7.5704 - val_y2_output_loss: 11.1084 - val_y1_output_root_mean_squared_error: 2.7898 - val_y2_output_root_mean_squared_error: 3.3653
# Epoch 13/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.0387 - y1_output_loss: 7.5445 - y2_output_loss: 11.4376 - y1_output_root_mean_squared_error: 2.7441 - y2_output_root_mean_squared_error: 3.3924 - val_loss: 21.5006 - val_y1_output_loss: 8.2104 - val_y2_output_loss: 12.8408 - val_y1_output_root_mean_squared_error: 2.9069 - val_y2_output_root_mean_squared_error: 3.6126
# Epoch 14/500
# 614/614 [==============================] - 0s 128us/sample - loss: 18.4252 - y1_output_loss: 7.5488 - y2_output_loss: 11.2353 - y1_output_root_mean_squared_error: 2.7282 - y2_output_root_mean_squared_error: 3.3139 - val_loss: 18.5275 - val_y1_output_loss: 6.4975 - val_y2_output_loss: 11.5140 - val_y1_output_root_mean_squared_error: 2.5929 - val_y2_output_root_mean_squared_error: 3.4357
# Epoch 15/500
# 614/614 [==============================] - 0s 127us/sample - loss: 19.4695 - y1_output_loss: 7.6881 - y2_output_loss: 11.7853 - y1_output_root_mean_squared_error: 2.7560 - y2_output_root_mean_squared_error: 3.4458 - val_loss: 25.3816 - val_y1_output_loss: 8.7381 - val_y2_output_loss: 16.5385 - val_y1_output_root_mean_squared_error: 2.9590 - val_y2_output_root_mean_squared_error: 4.0775
# Epoch 16/500
# 614/614 [==============================] - 0s 132us/sample - loss: 19.3742 - y1_output_loss: 7.5228 - y2_output_loss: 11.6745 - y1_output_root_mean_squared_error: 2.7545 - y2_output_root_mean_squared_error: 3.4332 - val_loss: 15.5496 - val_y1_output_loss: 5.4526 - val_y2_output_loss: 9.6938 - val_y1_output_root_mean_squared_error: 2.3702 - val_y2_output_root_mean_squared_error: 3.1515
# Epoch 17/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.8887 - y1_output_loss: 6.1025 - y2_output_loss: 8.7361 - y1_output_root_mean_squared_error: 2.4656 - y2_output_root_mean_squared_error: 2.9681 - val_loss: 16.7985 - val_y1_output_loss: 5.9367 - val_y2_output_loss: 10.3246 - val_y1_output_root_mean_squared_error: 2.4811 - val_y2_output_root_mean_squared_error: 3.2623
# Epoch 18/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.4034 - y1_output_loss: 6.2173 - y2_output_loss: 9.3384 - y1_output_root_mean_squared_error: 2.4861 - y2_output_root_mean_squared_error: 3.0369 - val_loss: 17.5018 - val_y1_output_loss: 7.0493 - val_y2_output_loss: 10.0220 - val_y1_output_root_mean_squared_error: 2.6829 - val_y2_output_root_mean_squared_error: 3.2100
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.9218 - y1_output_loss: 6.7838 - y2_output_loss: 10.1306 - y1_output_root_mean_squared_error: 2.6078 - y2_output_root_mean_squared_error: 3.1814 - val_loss: 20.6574 - val_y1_output_loss: 7.0750 - val_y2_output_loss: 13.1893 - val_y1_output_root_mean_squared_error: 2.6989 - val_y2_output_root_mean_squared_error: 3.6570
# Epoch 20/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.6111 - y1_output_loss: 5.9910 - y2_output_loss: 9.5289 - y1_output_root_mean_squared_error: 2.4512 - y2_output_root_mean_squared_error: 3.0989 - val_loss: 31.5047 - val_y1_output_loss: 9.6970 - val_y2_output_loss: 21.3895 - val_y1_output_root_mean_squared_error: 3.1473 - val_y2_output_root_mean_squared_error: 4.6475
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.1663 - y1_output_loss: 5.6812 - y2_output_loss: 8.5603 - y1_output_root_mean_squared_error: 2.3736 - y2_output_root_mean_squared_error: 2.9210 - val_loss: 21.5164 - val_y1_output_loss: 7.0061 - val_y2_output_loss: 13.9144 - val_y1_output_root_mean_squared_error: 2.6921 - val_y2_output_root_mean_squared_error: 3.7774
# Epoch 22/500
# 614/614 [==============================] - 0s 129us/sample - loss: 13.6712 - y1_output_loss: 5.4274 - y2_output_loss: 8.1469 - y1_output_root_mean_squared_error: 2.3403 - y2_output_root_mean_squared_error: 2.8625 - val_loss: 13.1828 - val_y1_output_loss: 4.2909 - val_y2_output_loss: 8.6179 - val_y1_output_root_mean_squared_error: 2.1024 - val_y2_output_root_mean_squared_error: 2.9602
# Epoch 23/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.4807 - y1_output_loss: 5.3604 - y2_output_loss: 9.0695 - y1_output_root_mean_squared_error: 2.3160 - y2_output_root_mean_squared_error: 3.0194 - val_loss: 25.4293 - val_y1_output_loss: 8.0073 - val_y2_output_loss: 17.1101 - val_y1_output_root_mean_squared_error: 2.8584 - val_y2_output_root_mean_squared_error: 4.1544
# Epoch 24/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.7147 - y1_output_loss: 5.3103 - y2_output_loss: 8.3629 - y1_output_root_mean_squared_error: 2.3068 - y2_output_root_mean_squared_error: 2.8971 - val_loss: 11.1915 - val_y1_output_loss: 3.5764 - val_y2_output_loss: 7.3019 - val_y1_output_root_mean_squared_error: 1.9223 - val_y2_output_root_mean_squared_error: 2.7380
# Epoch 25/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.1338 - y1_output_loss: 4.9086 - y2_output_loss: 8.1424 - y1_output_root_mean_squared_error: 2.2236 - y2_output_root_mean_squared_error: 2.8617 - val_loss: 12.6653 - val_y1_output_loss: 3.9436 - val_y2_output_loss: 8.4717 - val_y1_output_root_mean_squared_error: 2.0154 - val_y2_output_root_mean_squared_error: 2.9331
# Epoch 26/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.5177 - y1_output_loss: 4.9976 - y2_output_loss: 8.5522 - y1_output_root_mean_squared_error: 2.2291 - y2_output_root_mean_squared_error: 2.9238 - val_loss: 12.8992 - val_y1_output_loss: 4.3409 - val_y2_output_loss: 8.1718 - val_y1_output_root_mean_squared_error: 2.1196 - val_y2_output_root_mean_squared_error: 2.8994
# Epoch 27/500
# 614/614 [==============================] - 0s 133us/sample - loss: 12.8584 - y1_output_loss: 4.6783 - y2_output_loss: 8.1363 - y1_output_root_mean_squared_error: 2.1665 - y2_output_root_mean_squared_error: 2.8574 - val_loss: 16.6475 - val_y1_output_loss: 4.8483 - val_y2_output_loss: 11.3057 - val_y1_output_root_mean_squared_error: 2.2309 - val_y2_output_root_mean_squared_error: 3.4162
# Epoch 28/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.4164 - y1_output_loss: 4.6781 - y2_output_loss: 7.6514 - y1_output_root_mean_squared_error: 2.1715 - y2_output_root_mean_squared_error: 2.7751 - val_loss: 10.0803 - val_y1_output_loss: 3.0450 - val_y2_output_loss: 6.7550 - val_y1_output_root_mean_squared_error: 1.7772 - val_y2_output_root_mean_squared_error: 2.6310
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.0365 - y1_output_loss: 4.3097 - y2_output_loss: 6.6865 - y1_output_root_mean_squared_error: 2.0809 - y2_output_root_mean_squared_error: 2.5897 - val_loss: 19.9186 - val_y1_output_loss: 6.0725 - val_y2_output_loss: 13.2647 - val_y1_output_root_mean_squared_error: 2.5080 - val_y2_output_root_mean_squared_error: 3.6917
# Epoch 30/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.9641 - y1_output_loss: 4.0463 - y2_output_loss: 5.8658 - y1_output_root_mean_squared_error: 2.0160 - y2_output_root_mean_squared_error: 2.4290 - val_loss: 11.1593 - val_y1_output_loss: 3.0451 - val_y2_output_loss: 7.8493 - val_y1_output_root_mean_squared_error: 1.7737 - val_y2_output_root_mean_squared_error: 2.8308
# Epoch 31/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.8856 - y1_output_loss: 4.2535 - y2_output_loss: 7.6490 - y1_output_root_mean_squared_error: 2.0622 - y2_output_root_mean_squared_error: 2.7628 - val_loss: 13.6896 - val_y1_output_loss: 4.4237 - val_y2_output_loss: 8.9504 - val_y1_output_root_mean_squared_error: 2.1388 - val_y2_output_root_mean_squared_error: 3.0191
# Epoch 32/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.1411 - y1_output_loss: 4.2753 - y2_output_loss: 6.7703 - y1_output_root_mean_squared_error: 2.0755 - y2_output_root_mean_squared_error: 2.6141 - val_loss: 9.2260 - val_y1_output_loss: 2.7959 - val_y2_output_loss: 6.2163 - val_y1_output_root_mean_squared_error: 1.6970 - val_y2_output_root_mean_squared_error: 2.5192
# Epoch 33/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.6795 - y1_output_loss: 3.7046 - y2_output_loss: 5.8948 - y1_output_root_mean_squared_error: 1.9327 - y2_output_root_mean_squared_error: 2.4381 - val_loss: 10.5596 - val_y1_output_loss: 3.3416 - val_y2_output_loss: 6.9566 - val_y1_output_root_mean_squared_error: 1.8581 - val_y2_output_root_mean_squared_error: 2.6659
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.2902 - y1_output_loss: 3.6955 - y2_output_loss: 6.5477 - y1_output_root_mean_squared_error: 1.9196 - y2_output_root_mean_squared_error: 2.5701 - val_loss: 7.9640 - val_y1_output_loss: 2.3811 - val_y2_output_loss: 5.3802 - val_y1_output_root_mean_squared_error: 1.5672 - val_y2_output_root_mean_squared_error: 2.3468
# Epoch 35/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.6932 - y1_output_loss: 3.4106 - y2_output_loss: 5.2653 - y1_output_root_mean_squared_error: 1.8423 - y2_output_root_mean_squared_error: 2.3020 - val_loss: 9.2368 - val_y1_output_loss: 2.7386 - val_y2_output_loss: 6.2439 - val_y1_output_root_mean_squared_error: 1.6771 - val_y2_output_root_mean_squared_error: 2.5346
# Epoch 36/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.7531 - y1_output_loss: 3.4171 - y2_output_loss: 6.5089 - y1_output_root_mean_squared_error: 1.8394 - y2_output_root_mean_squared_error: 2.5239 - val_loss: 8.5031 - val_y1_output_loss: 2.5337 - val_y2_output_loss: 5.9247 - val_y1_output_root_mean_squared_error: 1.5846 - val_y2_output_root_mean_squared_error: 2.4479
# Epoch 37/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.3092 - y1_output_loss: 3.7758 - y2_output_loss: 7.8385 - y1_output_root_mean_squared_error: 1.9379 - y2_output_root_mean_squared_error: 2.7484 - val_loss: 42.3404 - val_y1_output_loss: 7.9544 - val_y2_output_loss: 33.2189 - val_y1_output_root_mean_squared_error: 2.8707 - val_y2_output_root_mean_squared_error: 5.8395
# Epoch 38/500
# 614/614 [==============================] - 0s 126us/sample - loss: 12.7179 - y1_output_loss: 4.1640 - y2_output_loss: 8.6052 - y1_output_root_mean_squared_error: 2.0327 - y2_output_root_mean_squared_error: 2.9302 - val_loss: 11.7729 - val_y1_output_loss: 3.8018 - val_y2_output_loss: 7.9019 - val_y1_output_root_mean_squared_error: 1.9609 - val_y2_output_root_mean_squared_error: 2.8156
# Epoch 39/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.5960 - y1_output_loss: 3.5442 - y2_output_loss: 6.0835 - y1_output_root_mean_squared_error: 1.8860 - y2_output_root_mean_squared_error: 2.4575 - val_loss: 13.3697 - val_y1_output_loss: 3.0591 - val_y2_output_loss: 10.3199 - val_y1_output_root_mean_squared_error: 1.7499 - val_y2_output_root_mean_squared_error: 3.2105
# Epoch 40/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.6294 - y1_output_loss: 3.1567 - y2_output_loss: 6.5915 - y1_output_root_mean_squared_error: 1.7629 - y2_output_root_mean_squared_error: 2.5537 - val_loss: 40.7357 - val_y1_output_loss: 8.8672 - val_y2_output_loss: 31.5826 - val_y1_output_root_mean_squared_error: 2.9999 - val_y2_output_root_mean_squared_error: 5.6335
# Epoch 41/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.5577 - y1_output_loss: 3.4214 - y2_output_loss: 6.0555 - y1_output_root_mean_squared_error: 1.8570 - y2_output_root_mean_squared_error: 2.4717 - val_loss: 9.7883 - val_y1_output_loss: 2.8319 - val_y2_output_loss: 6.7865 - val_y1_output_root_mean_squared_error: 1.7029 - val_y2_output_root_mean_squared_error: 2.6246
# Epoch 42/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.3026 - y1_output_loss: 2.7739 - y2_output_loss: 4.5038 - y1_output_root_mean_squared_error: 1.6713 - y2_output_root_mean_squared_error: 2.1235 - val_loss: 6.7837 - val_y1_output_loss: 1.7959 - val_y2_output_loss: 4.8719 - val_y1_output_root_mean_squared_error: 1.3509 - val_y2_output_root_mean_squared_error: 2.2268
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6615 - y1_output_loss: 2.4363 - y2_output_loss: 4.2106 - y1_output_root_mean_squared_error: 1.5553 - y2_output_root_mean_squared_error: 2.0598 - val_loss: 8.2588 - val_y1_output_loss: 2.1383 - val_y2_output_loss: 6.0121 - val_y1_output_root_mean_squared_error: 1.4779 - val_y2_output_root_mean_squared_error: 2.4646
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.6440 - y1_output_loss: 3.0264 - y2_output_loss: 5.7349 - y1_output_root_mean_squared_error: 1.7397 - y2_output_root_mean_squared_error: 2.3701 - val_loss: 8.5244 - val_y1_output_loss: 2.3376 - val_y2_output_loss: 6.0101 - val_y1_output_root_mean_squared_error: 1.5398 - val_y2_output_root_mean_squared_error: 2.4806
# Epoch 45/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.1632 - y1_output_loss: 2.7640 - y2_output_loss: 5.4306 - y1_output_root_mean_squared_error: 1.6635 - y2_output_root_mean_squared_error: 2.3229 - val_loss: 12.7486 - val_y1_output_loss: 3.1584 - val_y2_output_loss: 9.4954 - val_y1_output_root_mean_squared_error: 1.7746 - val_y2_output_root_mean_squared_error: 3.0983
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.6312 - y1_output_loss: 2.6532 - y2_output_loss: 4.9733 - y1_output_root_mean_squared_error: 1.6216 - y2_output_root_mean_squared_error: 2.2365 - val_loss: 6.8488 - val_y1_output_loss: 2.0001 - val_y2_output_loss: 4.7062 - val_y1_output_root_mean_squared_error: 1.4302 - val_y2_output_root_mean_squared_error: 2.1917
# Epoch 47/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.2075 - y1_output_loss: 2.4466 - y2_output_loss: 4.7917 - y1_output_root_mean_squared_error: 1.5608 - y2_output_root_mean_squared_error: 2.1843 - val_loss: 7.3173 - val_y1_output_loss: 1.7754 - val_y2_output_loss: 5.4005 - val_y1_output_root_mean_squared_error: 1.3462 - val_y2_output_root_mean_squared_error: 2.3463
# Epoch 48/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.5954 - y1_output_loss: 2.3917 - y2_output_loss: 5.1919 - y1_output_root_mean_squared_error: 1.5418 - y2_output_root_mean_squared_error: 2.2843 - val_loss: 7.0916 - val_y1_output_loss: 1.8998 - val_y2_output_loss: 5.1051 - val_y1_output_root_mean_squared_error: 1.3868 - val_y2_output_root_mean_squared_error: 2.2734
# Epoch 49/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.0563 - y1_output_loss: 2.1966 - y2_output_loss: 3.8207 - y1_output_root_mean_squared_error: 1.4849 - y2_output_root_mean_squared_error: 1.9625 - val_loss: 9.2990 - val_y1_output_loss: 2.5816 - val_y2_output_loss: 6.6499 - val_y1_output_root_mean_squared_error: 1.6166 - val_y2_output_root_mean_squared_error: 2.5856
# Epoch 50/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.0483 - y1_output_loss: 2.3153 - y2_output_loss: 5.6634 - y1_output_root_mean_squared_error: 1.5279 - y2_output_root_mean_squared_error: 2.3904 - val_loss: 7.3307 - val_y1_output_loss: 2.1568 - val_y2_output_loss: 5.0140 - val_y1_output_root_mean_squared_error: 1.4865 - val_y2_output_root_mean_squared_error: 2.2630
# Epoch 51/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.5156 - y1_output_loss: 2.5461 - y2_output_loss: 4.9589 - y1_output_root_mean_squared_error: 1.6000 - y2_output_root_mean_squared_error: 2.2261 - val_loss: 11.7869 - val_y1_output_loss: 3.2482 - val_y2_output_loss: 8.4026 - val_y1_output_root_mean_squared_error: 1.8189 - val_y2_output_root_mean_squared_error: 2.9118
# Epoch 52/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.2381 - y1_output_loss: 2.0539 - y2_output_loss: 4.2245 - y1_output_root_mean_squared_error: 1.4308 - y2_output_root_mean_squared_error: 2.0472 - val_loss: 18.2136 - val_y1_output_loss: 3.3346 - val_y2_output_loss: 14.6893 - val_y1_output_root_mean_squared_error: 1.8322 - val_y2_output_root_mean_squared_error: 3.8545
# Epoch 53/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.5200 - y1_output_loss: 2.3862 - y2_output_loss: 5.2557 - y1_output_root_mean_squared_error: 1.5488 - y2_output_root_mean_squared_error: 2.2630 - val_loss: 28.0357 - val_y1_output_loss: 5.0661 - val_y2_output_loss: 23.0017 - val_y1_output_root_mean_squared_error: 2.2339 - val_y2_output_root_mean_squared_error: 4.8006
# Epoch 54/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.0541 - y1_output_loss: 2.4742 - y2_output_loss: 5.5950 - y1_output_root_mean_squared_error: 1.5759 - y2_output_root_mean_squared_error: 2.3602 - val_loss: 20.2513 - val_y1_output_loss: 3.9576 - val_y2_output_loss: 16.3769 - val_y1_output_root_mean_squared_error: 1.9723 - val_y2_output_root_mean_squared_error: 4.0449
# Epoch 55/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.4205 - y1_output_loss: 2.0268 - y2_output_loss: 4.3458 - y1_output_root_mean_squared_error: 1.4302 - y2_output_root_mean_squared_error: 2.0916 - val_loss: 5.4721 - val_y1_output_loss: 1.3008 - val_y2_output_loss: 4.1073 - val_y1_output_root_mean_squared_error: 1.1415 - val_y2_output_root_mean_squared_error: 2.0418
# Epoch 56/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.5800 - y1_output_loss: 2.4419 - y2_output_loss: 5.1022 - y1_output_root_mean_squared_error: 1.5698 - y2_output_root_mean_squared_error: 2.2618 - val_loss: 6.8992 - val_y1_output_loss: 1.5189 - val_y2_output_loss: 5.3590 - val_y1_output_root_mean_squared_error: 1.2251 - val_y2_output_root_mean_squared_error: 2.3235
# Epoch 57/500
# 614/614 [==============================] - 0s 160us/sample - loss: 5.6986 - y1_output_loss: 1.9566 - y2_output_loss: 3.7525 - y1_output_root_mean_squared_error: 1.3924 - y2_output_root_mean_squared_error: 1.9391 - val_loss: 7.5535 - val_y1_output_loss: 1.4541 - val_y2_output_loss: 6.0146 - val_y1_output_root_mean_squared_error: 1.2175 - val_y2_output_root_mean_squared_error: 2.4640
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.1188 - y1_output_loss: 1.5017 - y2_output_loss: 3.5995 - y1_output_root_mean_squared_error: 1.2274 - y2_output_root_mean_squared_error: 1.9006 - val_loss: 6.4973 - val_y1_output_loss: 1.1398 - val_y2_output_loss: 5.3474 - val_y1_output_root_mean_squared_error: 1.0562 - val_y2_output_root_mean_squared_error: 2.3198
# Epoch 59/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.1667 - y1_output_loss: 1.6449 - y2_output_loss: 3.4942 - y1_output_root_mean_squared_error: 1.2818 - y2_output_root_mean_squared_error: 1.8772 - val_loss: 9.8728 - val_y1_output_loss: 2.8732 - val_y2_output_loss: 6.9584 - val_y1_output_root_mean_squared_error: 1.6992 - val_y2_output_root_mean_squared_error: 2.6430
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.8366 - y1_output_loss: 1.8007 - y2_output_loss: 3.9833 - y1_output_root_mean_squared_error: 1.3477 - y2_output_root_mean_squared_error: 2.0050 - val_loss: 6.8622 - val_y1_output_loss: 2.0302 - val_y2_output_loss: 4.7891 - val_y1_output_root_mean_squared_error: 1.4155 - val_y2_output_root_mean_squared_error: 2.2042
# Epoch 61/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.4942 - y1_output_loss: 1.6290 - y2_output_loss: 3.8326 - y1_output_root_mean_squared_error: 1.2823 - y2_output_root_mean_squared_error: 1.9621 - val_loss: 6.5076 - val_y1_output_loss: 1.3258 - val_y2_output_loss: 5.1403 - val_y1_output_root_mean_squared_error: 1.1429 - val_y2_output_root_mean_squared_error: 2.2806
# Epoch 62/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.3387 - y1_output_loss: 1.5524 - y2_output_loss: 3.7911 - y1_output_root_mean_squared_error: 1.2409 - y2_output_root_mean_squared_error: 1.9490 - val_loss: 4.9608 - val_y1_output_loss: 1.1642 - val_y2_output_loss: 3.7542 - val_y1_output_root_mean_squared_error: 1.0734 - val_y2_output_root_mean_squared_error: 1.9516
# Epoch 63/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3095 - y1_output_loss: 1.2518 - y2_output_loss: 3.0281 - y1_output_root_mean_squared_error: 1.1223 - y2_output_root_mean_squared_error: 1.7464 - val_loss: 5.6408 - val_y1_output_loss: 1.4907 - val_y2_output_loss: 4.0333 - val_y1_output_root_mean_squared_error: 1.2335 - val_y2_output_root_mean_squared_error: 2.0296
# Epoch 64/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.3516 - y1_output_loss: 1.2654 - y2_output_loss: 3.0483 - y1_output_root_mean_squared_error: 1.1301 - y2_output_root_mean_squared_error: 1.7534 - val_loss: 4.9549 - val_y1_output_loss: 0.9980 - val_y2_output_loss: 3.8352 - val_y1_output_root_mean_squared_error: 1.0113 - val_y2_output_root_mean_squared_error: 1.9830
# Epoch 65/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1560 - y1_output_loss: 1.1488 - y2_output_loss: 3.0347 - y1_output_root_mean_squared_error: 1.0750 - y2_output_root_mean_squared_error: 1.7322 - val_loss: 9.4866 - val_y1_output_loss: 1.2932 - val_y2_output_loss: 8.0685 - val_y1_output_root_mean_squared_error: 1.1373 - val_y2_output_root_mean_squared_error: 2.8624
# Epoch 66/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.8693 - y1_output_loss: 1.3669 - y2_output_loss: 3.4653 - y1_output_root_mean_squared_error: 1.1708 - y2_output_root_mean_squared_error: 1.8704 - val_loss: 4.2517 - val_y1_output_loss: 0.8182 - val_y2_output_loss: 3.3417 - val_y1_output_root_mean_squared_error: 0.9134 - val_y2_output_root_mean_squared_error: 1.8486
# Epoch 67/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6287 - y1_output_loss: 1.0732 - y2_output_loss: 2.5882 - y1_output_root_mean_squared_error: 1.0333 - y2_output_root_mean_squared_error: 1.6003 - val_loss: 6.3552 - val_y1_output_loss: 0.9004 - val_y2_output_loss: 5.3311 - val_y1_output_root_mean_squared_error: 0.9579 - val_y2_output_root_mean_squared_error: 2.3319
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.2161 - y1_output_loss: 1.1483 - y2_output_loss: 3.0487 - y1_output_root_mean_squared_error: 1.0754 - y2_output_root_mean_squared_error: 1.7492 - val_loss: 6.0885 - val_y1_output_loss: 1.0384 - val_y2_output_loss: 4.9323 - val_y1_output_root_mean_squared_error: 1.0269 - val_y2_output_root_mean_squared_error: 2.2437
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.3679 - y1_output_loss: 1.2818 - y2_output_loss: 3.0674 - y1_output_root_mean_squared_error: 1.1324 - y2_output_root_mean_squared_error: 1.7566 - val_loss: 5.8915 - val_y1_output_loss: 1.7938 - val_y2_output_loss: 3.9488 - val_y1_output_root_mean_squared_error: 1.3568 - val_y2_output_root_mean_squared_error: 2.0126
# Epoch 70/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8349 - y1_output_loss: 1.2087 - y2_output_loss: 3.5961 - y1_output_root_mean_squared_error: 1.1023 - y2_output_root_mean_squared_error: 1.9026 - val_loss: 5.7440 - val_y1_output_loss: 1.8087 - val_y2_output_loss: 3.8294 - val_y1_output_root_mean_squared_error: 1.3478 - val_y2_output_root_mean_squared_error: 1.9818
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.9648 - y1_output_loss: 1.7105 - y2_output_loss: 4.2248 - y1_output_root_mean_squared_error: 1.3091 - y2_output_root_mean_squared_error: 2.0618 - val_loss: 7.1074 - val_y1_output_loss: 2.3988 - val_y2_output_loss: 4.6187 - val_y1_output_root_mean_squared_error: 1.5540 - val_y2_output_root_mean_squared_error: 2.1662
# Epoch 72/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.9649 - y1_output_loss: 1.0988 - y2_output_loss: 2.8681 - y1_output_root_mean_squared_error: 1.0504 - y2_output_root_mean_squared_error: 1.6916 - val_loss: 6.8438 - val_y1_output_loss: 1.3357 - val_y2_output_loss: 5.6113 - val_y1_output_root_mean_squared_error: 1.1189 - val_y2_output_root_mean_squared_error: 2.3647
# Epoch 73/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3495 - y1_output_loss: 0.8645 - y2_output_loss: 2.4701 - y1_output_root_mean_squared_error: 0.9328 - y2_output_root_mean_squared_error: 1.5746 - val_loss: 3.8635 - val_y1_output_loss: 0.6899 - val_y2_output_loss: 3.0648 - val_y1_output_root_mean_squared_error: 0.8396 - val_y2_output_root_mean_squared_error: 1.7773
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6496 - y1_output_loss: 0.8821 - y2_output_loss: 2.7753 - y1_output_root_mean_squared_error: 0.9354 - y2_output_root_mean_squared_error: 1.6657 - val_loss: 7.9816 - val_y1_output_loss: 1.7963 - val_y2_output_loss: 6.1032 - val_y1_output_root_mean_squared_error: 1.3483 - val_y2_output_root_mean_squared_error: 2.4827
# Epoch 75/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5776 - y1_output_loss: 0.8988 - y2_output_loss: 2.6604 - y1_output_root_mean_squared_error: 0.9510 - y2_output_root_mean_squared_error: 1.6350 - val_loss: 4.4428 - val_y1_output_loss: 0.6745 - val_y2_output_loss: 3.6860 - val_y1_output_root_mean_squared_error: 0.8242 - val_y2_output_root_mean_squared_error: 1.9400
# Epoch 76/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.3359 - y1_output_loss: 1.0673 - y2_output_loss: 3.2664 - y1_output_root_mean_squared_error: 1.0377 - y2_output_root_mean_squared_error: 1.8053 - val_loss: 5.1042 - val_y1_output_loss: 0.9404 - val_y2_output_loss: 4.0168 - val_y1_output_root_mean_squared_error: 0.9816 - val_y2_output_root_mean_squared_error: 2.0348
# Epoch 77/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.5424 - y1_output_loss: 1.0540 - y2_output_loss: 3.4595 - y1_output_root_mean_squared_error: 1.0304 - y2_output_root_mean_squared_error: 1.8656 - val_loss: 3.4466 - val_y1_output_loss: 0.6471 - val_y2_output_loss: 2.7119 - val_y1_output_root_mean_squared_error: 0.8074 - val_y2_output_root_mean_squared_error: 1.6717
# Epoch 78/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3915 - y1_output_loss: 0.9042 - y2_output_loss: 2.4825 - y1_output_root_mean_squared_error: 0.9470 - y2_output_root_mean_squared_error: 1.5794 - val_loss: 4.6126 - val_y1_output_loss: 0.8228 - val_y2_output_loss: 3.7401 - val_y1_output_root_mean_squared_error: 0.9081 - val_y2_output_root_mean_squared_error: 1.9463
# Epoch 79/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2327 - y1_output_loss: 0.7350 - y2_output_loss: 2.4819 - y1_output_root_mean_squared_error: 0.8573 - y2_output_root_mean_squared_error: 1.5804 - val_loss: 3.8292 - val_y1_output_loss: 0.6866 - val_y2_output_loss: 3.0937 - val_y1_output_root_mean_squared_error: 0.8220 - val_y2_output_root_mean_squared_error: 1.7758
# Epoch 80/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1377 - y1_output_loss: 0.8296 - y2_output_loss: 2.3067 - y1_output_root_mean_squared_error: 0.9104 - y2_output_root_mean_squared_error: 1.5195 - val_loss: 7.4140 - val_y1_output_loss: 1.7673 - val_y2_output_loss: 5.5810 - val_y1_output_root_mean_squared_error: 1.3344 - val_y2_output_root_mean_squared_error: 2.3735
# Epoch 81/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1209 - y1_output_loss: 1.2133 - y2_output_loss: 2.8905 - y1_output_root_mean_squared_error: 1.1051 - y2_output_root_mean_squared_error: 1.7029 - val_loss: 4.5958 - val_y1_output_loss: 1.0035 - val_y2_output_loss: 3.4737 - val_y1_output_root_mean_squared_error: 1.0104 - val_y2_output_root_mean_squared_error: 1.8908
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0576 - y1_output_loss: 0.7122 - y2_output_loss: 2.3429 - y1_output_root_mean_squared_error: 0.8452 - y2_output_root_mean_squared_error: 1.5308 - val_loss: 3.3441 - val_y1_output_loss: 0.6599 - val_y2_output_loss: 2.6024 - val_y1_output_root_mean_squared_error: 0.8126 - val_y2_output_root_mean_squared_error: 1.6382
# Epoch 83/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1427 - y1_output_loss: 0.7979 - y2_output_loss: 2.3382 - y1_output_root_mean_squared_error: 0.8856 - y2_output_root_mean_squared_error: 1.5357 - val_loss: 3.5951 - val_y1_output_loss: 0.8554 - val_y2_output_loss: 2.6262 - val_y1_output_root_mean_squared_error: 0.9371 - val_y2_output_root_mean_squared_error: 1.6483
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.5709 - y1_output_loss: 0.9419 - y2_output_loss: 2.6438 - y1_output_root_mean_squared_error: 0.9748 - y2_output_root_mean_squared_error: 1.6189 - val_loss: 4.7822 - val_y1_output_loss: 0.7675 - val_y2_output_loss: 3.9993 - val_y1_output_root_mean_squared_error: 0.8573 - val_y2_output_root_mean_squared_error: 2.0118
# Epoch 85/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.4032 - y1_output_loss: 0.7157 - y2_output_loss: 2.6645 - y1_output_root_mean_squared_error: 0.8495 - y2_output_root_mean_squared_error: 1.6376 - val_loss: 3.7583 - val_y1_output_loss: 0.6312 - val_y2_output_loss: 3.0511 - val_y1_output_root_mean_squared_error: 0.7868 - val_y2_output_root_mean_squared_error: 1.7718
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7748 - y1_output_loss: 0.7382 - y2_output_loss: 2.0192 - y1_output_root_mean_squared_error: 0.8620 - y2_output_root_mean_squared_error: 1.4254 - val_loss: 4.4356 - val_y1_output_loss: 0.6336 - val_y2_output_loss: 3.6836 - val_y1_output_root_mean_squared_error: 0.8089 - val_y2_output_root_mean_squared_error: 1.9446
# Epoch 87/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5243 - y1_output_loss: 1.2795 - y2_output_loss: 3.2451 - y1_output_root_mean_squared_error: 1.1345 - y2_output_root_mean_squared_error: 1.7992 - val_loss: 3.3038 - val_y1_output_loss: 0.5862 - val_y2_output_loss: 2.6109 - val_y1_output_root_mean_squared_error: 0.7746 - val_y2_output_root_mean_squared_error: 1.6443
# Epoch 88/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3680 - y1_output_loss: 0.8523 - y2_output_loss: 2.5201 - y1_output_root_mean_squared_error: 0.9246 - y2_output_root_mean_squared_error: 1.5853 - val_loss: 3.5394 - val_y1_output_loss: 0.5139 - val_y2_output_loss: 2.9262 - val_y1_output_root_mean_squared_error: 0.7302 - val_y2_output_root_mean_squared_error: 1.7338
# Epoch 89/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7656 - y1_output_loss: 0.7046 - y2_output_loss: 2.0542 - y1_output_root_mean_squared_error: 0.8429 - y2_output_root_mean_squared_error: 1.4336 - val_loss: 4.3693 - val_y1_output_loss: 1.1337 - val_y2_output_loss: 3.1090 - val_y1_output_root_mean_squared_error: 1.0809 - val_y2_output_root_mean_squared_error: 1.7891
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.4626 - y1_output_loss: 0.9269 - y2_output_loss: 2.5275 - y1_output_root_mean_squared_error: 0.9656 - y2_output_root_mean_squared_error: 1.5907 - val_loss: 4.0733 - val_y1_output_loss: 0.8725 - val_y2_output_loss: 3.0744 - val_y1_output_root_mean_squared_error: 0.9506 - val_y2_output_root_mean_squared_error: 1.7804
# Epoch 91/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1933 - y1_output_loss: 0.7893 - y2_output_loss: 2.3749 - y1_output_root_mean_squared_error: 0.8919 - y2_output_root_mean_squared_error: 1.5485 - val_loss: 3.2637 - val_y1_output_loss: 0.7051 - val_y2_output_loss: 2.4591 - val_y1_output_root_mean_squared_error: 0.8493 - val_y2_output_root_mean_squared_error: 1.5945
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.8662 - y1_output_loss: 1.0907 - y2_output_loss: 2.7495 - y1_output_root_mean_squared_error: 1.0486 - y2_output_root_mean_squared_error: 1.6633 - val_loss: 4.8340 - val_y1_output_loss: 0.5934 - val_y2_output_loss: 4.1418 - val_y1_output_root_mean_squared_error: 0.7730 - val_y2_output_root_mean_squared_error: 2.0583
# Epoch 93/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.9491 - y1_output_loss: 1.0588 - y2_output_loss: 2.8613 - y1_output_root_mean_squared_error: 1.0300 - y2_output_root_mean_squared_error: 1.6995 - val_loss: 3.7063 - val_y1_output_loss: 0.9302 - val_y2_output_loss: 2.6608 - val_y1_output_root_mean_squared_error: 0.9756 - val_y2_output_root_mean_squared_error: 1.6597
# Epoch 94/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.8438 - y1_output_loss: 0.6287 - y2_output_loss: 2.1954 - y1_output_root_mean_squared_error: 0.7927 - y2_output_root_mean_squared_error: 1.4884 - val_loss: 3.0647 - val_y1_output_loss: 0.6297 - val_y2_output_loss: 2.4187 - val_y1_output_root_mean_squared_error: 0.7730 - val_y2_output_root_mean_squared_error: 1.5707
# Epoch 95/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5849 - y1_output_loss: 0.5661 - y2_output_loss: 2.0449 - y1_output_root_mean_squared_error: 0.7537 - y2_output_root_mean_squared_error: 1.4202 - val_loss: 6.0853 - val_y1_output_loss: 0.6822 - val_y2_output_loss: 5.3633 - val_y1_output_root_mean_squared_error: 0.8235 - val_y2_output_root_mean_squared_error: 2.3253
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.9667 - y1_output_loss: 2.1463 - y2_output_loss: 4.9267 - y1_output_root_mean_squared_error: 1.4666 - y2_output_root_mean_squared_error: 2.1945 - val_loss: 25.7854 - val_y1_output_loss: 2.8187 - val_y2_output_loss: 22.6888 - val_y1_output_root_mean_squared_error: 1.6939 - val_y2_output_root_mean_squared_error: 4.7871
# Epoch 97/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6512 - y1_output_loss: 0.9363 - y2_output_loss: 2.7028 - y1_output_root_mean_squared_error: 0.9675 - y2_output_root_mean_squared_error: 1.6478 - val_loss: 4.4493 - val_y1_output_loss: 0.6148 - val_y2_output_loss: 3.7700 - val_y1_output_root_mean_squared_error: 0.7946 - val_y2_output_root_mean_squared_error: 1.9540
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3960 - y1_output_loss: 0.5567 - y2_output_loss: 1.8290 - y1_output_root_mean_squared_error: 0.7491 - y2_output_root_mean_squared_error: 1.3546 - val_loss: 3.1099 - val_y1_output_loss: 0.4637 - val_y2_output_loss: 2.5572 - val_y1_output_root_mean_squared_error: 0.6835 - val_y2_output_root_mean_squared_error: 1.6257
# Epoch 99/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4990 - y1_output_loss: 0.5665 - y2_output_loss: 1.9482 - y1_output_root_mean_squared_error: 0.7548 - y2_output_root_mean_squared_error: 1.3890 - val_loss: 6.4639 - val_y1_output_loss: 0.4651 - val_y2_output_loss: 5.8652 - val_y1_output_root_mean_squared_error: 0.6899 - val_y2_output_root_mean_squared_error: 2.4470
# Epoch 100/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0692 - y1_output_loss: 0.7564 - y2_output_loss: 2.2866 - y1_output_root_mean_squared_error: 0.8730 - y2_output_root_mean_squared_error: 1.5189 - val_loss: 3.0990 - val_y1_output_loss: 0.4969 - val_y2_output_loss: 2.5225 - val_y1_output_root_mean_squared_error: 0.7145 - val_y2_output_root_mean_squared_error: 1.6089
# Epoch 101/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.9432 - y1_output_loss: 1.7863 - y2_output_loss: 4.1258 - y1_output_root_mean_squared_error: 1.3382 - y2_output_root_mean_squared_error: 2.0378 - val_loss: 4.9985 - val_y1_output_loss: 1.1912 - val_y2_output_loss: 3.7654 - val_y1_output_root_mean_squared_error: 1.0902 - val_y2_output_root_mean_squared_error: 1.9519
# Epoch 102/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1853 - y1_output_loss: 0.7446 - y2_output_loss: 2.4229 - y1_output_root_mean_squared_error: 0.8655 - y2_output_root_mean_squared_error: 1.5608 - val_loss: 3.8550 - val_y1_output_loss: 0.5734 - val_y2_output_loss: 3.1737 - val_y1_output_root_mean_squared_error: 0.7676 - val_y2_output_root_mean_squared_error: 1.8071
# Epoch 103/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4045 - y1_output_loss: 0.5177 - y2_output_loss: 1.8687 - y1_output_root_mean_squared_error: 0.7198 - y2_output_root_mean_squared_error: 1.3735 - val_loss: 2.9995 - val_y1_output_loss: 0.4932 - val_y2_output_loss: 2.4150 - val_y1_output_root_mean_squared_error: 0.7119 - val_y2_output_root_mean_squared_error: 1.5788
# Epoch 104/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3260 - y1_output_loss: 0.5961 - y2_output_loss: 1.7181 - y1_output_root_mean_squared_error: 0.7752 - y2_output_root_mean_squared_error: 1.3134 - val_loss: 2.7864 - val_y1_output_loss: 0.4662 - val_y2_output_loss: 2.2345 - val_y1_output_root_mean_squared_error: 0.6897 - val_y2_output_root_mean_squared_error: 1.5201
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3907 - y1_output_loss: 0.5989 - y2_output_loss: 1.7949 - y1_output_root_mean_squared_error: 0.7640 - y2_output_root_mean_squared_error: 1.3442 - val_loss: 2.7054 - val_y1_output_loss: 0.4972 - val_y2_output_loss: 2.1652 - val_y1_output_root_mean_squared_error: 0.6957 - val_y2_output_root_mean_squared_error: 1.4905
# Epoch 106/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6791 - y1_output_loss: 0.6211 - y2_output_loss: 2.0529 - y1_output_root_mean_squared_error: 0.7896 - y2_output_root_mean_squared_error: 1.4338 - val_loss: 3.1307 - val_y1_output_loss: 0.6336 - val_y2_output_loss: 2.4533 - val_y1_output_root_mean_squared_error: 0.7877 - val_y2_output_root_mean_squared_error: 1.5844
# Epoch 107/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6416 - y1_output_loss: 0.6634 - y2_output_loss: 2.0402 - y1_output_root_mean_squared_error: 0.8166 - y2_output_root_mean_squared_error: 1.4053 - val_loss: 22.8460 - val_y1_output_loss: 1.8737 - val_y2_output_loss: 20.9350 - val_y1_output_root_mean_squared_error: 1.3721 - val_y2_output_root_mean_squared_error: 4.5786
# Epoch 108/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.7856 - y1_output_loss: 0.9646 - y2_output_loss: 2.8101 - y1_output_root_mean_squared_error: 0.9783 - y2_output_root_mean_squared_error: 1.6818 - val_loss: 2.8479 - val_y1_output_loss: 0.5457 - val_y2_output_loss: 2.2078 - val_y1_output_root_mean_squared_error: 0.7523 - val_y2_output_root_mean_squared_error: 1.5106
# Epoch 109/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.4821 - y1_output_loss: 0.5812 - y2_output_loss: 1.9183 - y1_output_root_mean_squared_error: 0.7645 - y2_output_root_mean_squared_error: 1.3776 - val_loss: 10.6152 - val_y1_output_loss: 1.7623 - val_y2_output_loss: 8.8352 - val_y1_output_root_mean_squared_error: 1.3298 - val_y2_output_root_mean_squared_error: 2.9743
# Epoch 110/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6787 - y1_output_loss: 0.7355 - y2_output_loss: 1.9296 - y1_output_root_mean_squared_error: 0.8583 - y2_output_root_mean_squared_error: 1.3936 - val_loss: 10.3482 - val_y1_output_loss: 3.5721 - val_y2_output_loss: 6.4944 - val_y1_output_root_mean_squared_error: 1.9171 - val_y2_output_root_mean_squared_error: 2.5832
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8937 - y1_output_loss: 0.7460 - y2_output_loss: 2.1500 - y1_output_root_mean_squared_error: 0.8634 - y2_output_root_mean_squared_error: 1.4657 - val_loss: 6.3670 - val_y1_output_loss: 1.0121 - val_y2_output_loss: 5.2385 - val_y1_output_root_mean_squared_error: 1.0098 - val_y2_output_root_mean_squared_error: 2.3124
# Epoch 112/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2774 - y1_output_loss: 0.7672 - y2_output_loss: 2.4954 - y1_output_root_mean_squared_error: 0.8716 - y2_output_root_mean_squared_error: 1.5868 - val_loss: 4.4635 - val_y1_output_loss: 0.6017 - val_y2_output_loss: 3.7263 - val_y1_output_root_mean_squared_error: 0.7899 - val_y2_output_root_mean_squared_error: 1.9595
# Epoch 113/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.2357 - y1_output_loss: 0.6042 - y2_output_loss: 1.6189 - y1_output_root_mean_squared_error: 0.7788 - y2_output_root_mean_squared_error: 1.2764 - val_loss: 2.7196 - val_y1_output_loss: 0.4262 - val_y2_output_loss: 2.2786 - val_y1_output_root_mean_squared_error: 0.6511 - val_y2_output_root_mean_squared_error: 1.5152
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.1841 - y1_output_loss: 0.5500 - y2_output_loss: 1.6205 - y1_output_root_mean_squared_error: 0.7412 - y2_output_root_mean_squared_error: 1.2786 - val_loss: 2.4362 - val_y1_output_loss: 0.4098 - val_y2_output_loss: 1.9406 - val_y1_output_root_mean_squared_error: 0.6503 - val_y2_output_root_mean_squared_error: 1.4189
# Epoch 115/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.9050 - y1_output_loss: 0.4326 - y2_output_loss: 1.4594 - y1_output_root_mean_squared_error: 0.6595 - y2_output_root_mean_squared_error: 1.2125 - val_loss: 2.6974 - val_y1_output_loss: 0.4136 - val_y2_output_loss: 2.2146 - val_y1_output_root_mean_squared_error: 0.6523 - val_y2_output_root_mean_squared_error: 1.5073
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.9993 - y1_output_loss: 0.5257 - y2_output_loss: 1.4592 - y1_output_root_mean_squared_error: 0.7278 - y2_output_root_mean_squared_error: 1.2123 - val_loss: 2.4221 - val_y1_output_loss: 0.4037 - val_y2_output_loss: 1.9524 - val_y1_output_root_mean_squared_error: 0.6414 - val_y2_output_root_mean_squared_error: 1.4180
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.5580 - y1_output_loss: 0.7188 - y2_output_loss: 1.8265 - y1_output_root_mean_squared_error: 0.8494 - y2_output_root_mean_squared_error: 1.3552 - val_loss: 2.7437 - val_y1_output_loss: 0.5044 - val_y2_output_loss: 2.1481 - val_y1_output_root_mean_squared_error: 0.7229 - val_y2_output_root_mean_squared_error: 1.4904
# Epoch 118/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.1501 - y1_output_loss: 0.4914 - y2_output_loss: 1.6457 - y1_output_root_mean_squared_error: 0.7028 - y2_output_root_mean_squared_error: 1.2869 - val_loss: 2.6371 - val_y1_output_loss: 0.4814 - val_y2_output_loss: 2.1808 - val_y1_output_root_mean_squared_error: 0.6695 - val_y2_output_root_mean_squared_error: 1.4795
# Epoch 119/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7381 - y1_output_loss: 0.6461 - y2_output_loss: 2.0808 - y1_output_root_mean_squared_error: 0.8063 - y2_output_root_mean_squared_error: 1.4449 - val_loss: 2.8900 - val_y1_output_loss: 0.3933 - val_y2_output_loss: 2.4632 - val_y1_output_root_mean_squared_error: 0.6293 - val_y2_output_root_mean_squared_error: 1.5792
# Epoch 120/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.4726 - y1_output_loss: 0.5422 - y2_output_loss: 1.9121 - y1_output_root_mean_squared_error: 0.7386 - y2_output_root_mean_squared_error: 1.3882 - val_loss: 2.5623 - val_y1_output_loss: 0.4793 - val_y2_output_loss: 2.0041 - val_y1_output_root_mean_squared_error: 0.7032 - val_y2_output_root_mean_squared_error: 1.4380
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3679 - y1_output_loss: 0.1231 - y2_output_loss: 0.2431 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.4942 - val_loss: 0.7202 - val_y1_output_loss: 0.1547 - val_y2_output_loss: 0.5503 - val_y1_output_root_mean_squared_error: 0.3972 - val_y2_output_root_mean_squared_error: 0.7500
# Epoch 462/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3932 - y1_output_loss: 0.1207 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5235 - val_loss: 0.9184 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 0.7364 - val_y1_output_root_mean_squared_error: 0.4281 - val_y2_output_root_mean_squared_error: 0.8574
# Epoch 463/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3491 - y1_output_loss: 0.1168 - y2_output_loss: 0.2479 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.4812 - val_loss: 1.7290 - val_y1_output_loss: 0.2329 - val_y2_output_loss: 1.5145 - val_y1_output_root_mean_squared_error: 0.4812 - val_y2_output_root_mean_squared_error: 1.2237
# Epoch 464/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4630 - y1_output_loss: 0.1357 - y2_output_loss: 0.3255 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.5722 - val_loss: 1.0505 - val_y1_output_loss: 0.2172 - val_y2_output_loss: 0.8015 - val_y1_output_root_mean_squared_error: 0.4685 - val_y2_output_root_mean_squared_error: 0.9116
# Epoch 465/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4302 - y1_output_loss: 0.1370 - y2_output_loss: 0.2919 - y1_output_root_mean_squared_error: 0.3709 - y2_output_root_mean_squared_error: 0.5410 - val_loss: 0.8543 - val_y1_output_loss: 0.1659 - val_y2_output_loss: 0.6692 - val_y1_output_root_mean_squared_error: 0.4064 - val_y2_output_root_mean_squared_error: 0.8302
# Epoch 466/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5401 - y1_output_loss: 0.1849 - y2_output_loss: 0.3515 - y1_output_root_mean_squared_error: 0.4315 - y2_output_root_mean_squared_error: 0.5949 - val_loss: 0.8484 - val_y1_output_loss: 0.1810 - val_y2_output_loss: 0.6398 - val_y1_output_root_mean_squared_error: 0.4308 - val_y2_output_root_mean_squared_error: 0.8141
# Epoch 467/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4429 - y1_output_loss: 0.1130 - y2_output_loss: 0.3301 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.5764 - val_loss: 0.8074 - val_y1_output_loss: 0.2110 - val_y2_output_loss: 0.5961 - val_y1_output_root_mean_squared_error: 0.4480 - val_y2_output_root_mean_squared_error: 0.7789
# Epoch 468/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4562 - y1_output_loss: 0.1352 - y2_output_loss: 0.3174 - y1_output_root_mean_squared_error: 0.3693 - y2_output_root_mean_squared_error: 0.5655 - val_loss: 0.9586 - val_y1_output_loss: 0.2148 - val_y2_output_loss: 0.7428 - val_y1_output_root_mean_squared_error: 0.4574 - val_y2_output_root_mean_squared_error: 0.8657
# Epoch 469/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5162 - y1_output_loss: 0.1645 - y2_output_loss: 0.3568 - y1_output_root_mean_squared_error: 0.4050 - y2_output_root_mean_squared_error: 0.5934 - val_loss: 2.7667 - val_y1_output_loss: 0.6666 - val_y2_output_loss: 2.0221 - val_y1_output_root_mean_squared_error: 0.8251 - val_y2_output_root_mean_squared_error: 1.4443
# Epoch 470/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5005 - y1_output_loss: 0.1616 - y2_output_loss: 0.3365 - y1_output_root_mean_squared_error: 0.4026 - y2_output_root_mean_squared_error: 0.5817 - val_loss: 0.9166 - val_y1_output_loss: 0.1970 - val_y2_output_loss: 0.6925 - val_y1_output_root_mean_squared_error: 0.4511 - val_y2_output_root_mean_squared_error: 0.8445
# Epoch 471/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3822 - y1_output_loss: 0.1145 - y2_output_loss: 0.2653 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.5174 - val_loss: 0.7629 - val_y1_output_loss: 0.2081 - val_y2_output_loss: 0.5550 - val_y1_output_root_mean_squared_error: 0.4491 - val_y2_output_root_mean_squared_error: 0.7492
# Epoch 472/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3558 - y1_output_loss: 0.1236 - y2_output_loss: 0.2299 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.4814 - val_loss: 0.8084 - val_y1_output_loss: 0.2043 - val_y2_output_loss: 0.5820 - val_y1_output_root_mean_squared_error: 0.4548 - val_y2_output_root_mean_squared_error: 0.7756
# Epoch 473/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3211 - y1_output_loss: 0.1024 - y2_output_loss: 0.2168 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.4678 - val_loss: 0.8931 - val_y1_output_loss: 0.2810 - val_y2_output_loss: 0.6090 - val_y1_output_root_mean_squared_error: 0.5159 - val_y2_output_root_mean_squared_error: 0.7918
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3112 - y1_output_loss: 0.1081 - y2_output_loss: 0.2031 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.4511 - val_loss: 0.7951 - val_y1_output_loss: 0.1951 - val_y2_output_loss: 0.5905 - val_y1_output_root_mean_squared_error: 0.4401 - val_y2_output_root_mean_squared_error: 0.7755
# Epoch 475/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4259 - y1_output_loss: 0.1278 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.5451 - val_loss: 1.4813 - val_y1_output_loss: 0.1901 - val_y2_output_loss: 1.2440 - val_y1_output_root_mean_squared_error: 0.4423 - val_y2_output_root_mean_squared_error: 1.1339
# Epoch 476/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4186 - y1_output_loss: 0.1214 - y2_output_loss: 0.2948 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5445 - val_loss: 0.8069 - val_y1_output_loss: 0.2355 - val_y2_output_loss: 0.5768 - val_y1_output_root_mean_squared_error: 0.4760 - val_y2_output_root_mean_squared_error: 0.7618
# Epoch 477/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3185 - y1_output_loss: 0.1128 - y2_output_loss: 0.2044 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4536 - val_loss: 0.7839 - val_y1_output_loss: 0.1917 - val_y2_output_loss: 0.5722 - val_y1_output_root_mean_squared_error: 0.4409 - val_y2_output_root_mean_squared_error: 0.7678
# Epoch 478/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4791 - y1_output_loss: 0.1352 - y2_output_loss: 0.3426 - y1_output_root_mean_squared_error: 0.3679 - y2_output_root_mean_squared_error: 0.5863 - val_loss: 0.8566 - val_y1_output_loss: 0.2099 - val_y2_output_loss: 0.6200 - val_y1_output_root_mean_squared_error: 0.4636 - val_y2_output_root_mean_squared_error: 0.8010
# Epoch 479/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3883 - y1_output_loss: 0.1231 - y2_output_loss: 0.2631 - y1_output_root_mean_squared_error: 0.3522 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 1.0254 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.8059 - val_y1_output_root_mean_squared_error: 0.4370 - val_y2_output_root_mean_squared_error: 0.9135
# Epoch 480/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3640 - y1_output_loss: 0.1133 - y2_output_loss: 0.2527 - y1_output_root_mean_squared_error: 0.3361 - y2_output_root_mean_squared_error: 0.5010 - val_loss: 1.8041 - val_y1_output_loss: 0.2653 - val_y2_output_loss: 1.4812 - val_y1_output_root_mean_squared_error: 0.5222 - val_y2_output_root_mean_squared_error: 1.2375
# Epoch 481/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3814 - y1_output_loss: 0.1164 - y2_output_loss: 0.2677 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.5139 - val_loss: 0.8709 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 0.6993 - val_y1_output_root_mean_squared_error: 0.4256 - val_y2_output_root_mean_squared_error: 0.8305
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5872 - y1_output_loss: 0.1589 - y2_output_loss: 0.4252 - y1_output_root_mean_squared_error: 0.3994 - y2_output_root_mean_squared_error: 0.6540 - val_loss: 0.8131 - val_y1_output_loss: 0.2127 - val_y2_output_loss: 0.5761 - val_y1_output_root_mean_squared_error: 0.4657 - val_y2_output_root_mean_squared_error: 0.7721
# Epoch 483/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3757 - y1_output_loss: 0.1227 - y2_output_loss: 0.2503 - y1_output_root_mean_squared_error: 0.3514 - y2_output_root_mean_squared_error: 0.5022 - val_loss: 0.7625 - val_y1_output_loss: 0.1801 - val_y2_output_loss: 0.5836 - val_y1_output_root_mean_squared_error: 0.4261 - val_y2_output_root_mean_squared_error: 0.7622
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3801 - y1_output_loss: 0.1200 - y2_output_loss: 0.2642 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.5121 - val_loss: 1.1875 - val_y1_output_loss: 0.5202 - val_y2_output_loss: 0.6376 - val_y1_output_root_mean_squared_error: 0.7276 - val_y2_output_root_mean_squared_error: 0.8113
# Epoch 485/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4822 - y1_output_loss: 0.1429 - y2_output_loss: 0.3382 - y1_output_root_mean_squared_error: 0.3792 - y2_output_root_mean_squared_error: 0.5817 - val_loss: 0.9442 - val_y1_output_loss: 0.2040 - val_y2_output_loss: 0.7215 - val_y1_output_root_mean_squared_error: 0.4584 - val_y2_output_root_mean_squared_error: 0.8568
# Epoch 486/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4274 - y1_output_loss: 0.1440 - y2_output_loss: 0.2837 - y1_output_root_mean_squared_error: 0.3807 - y2_output_root_mean_squared_error: 0.5315 - val_loss: 0.8354 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.6191 - val_y1_output_root_mean_squared_error: 0.4428 - val_y2_output_root_mean_squared_error: 0.7995
# Epoch 487/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4481 - y1_output_loss: 0.1242 - y2_output_loss: 0.3207 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5684 - val_loss: 0.9552 - val_y1_output_loss: 0.1781 - val_y2_output_loss: 0.7495 - val_y1_output_root_mean_squared_error: 0.4224 - val_y2_output_root_mean_squared_error: 0.8814
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4854 - y1_output_loss: 0.1529 - y2_output_loss: 0.3300 - y1_output_root_mean_squared_error: 0.3921 - y2_output_root_mean_squared_error: 0.5759 - val_loss: 0.8021 - val_y1_output_loss: 0.1688 - val_y2_output_loss: 0.6312 - val_y1_output_root_mean_squared_error: 0.4102 - val_y2_output_root_mean_squared_error: 0.7962
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3867 - y1_output_loss: 0.1108 - y2_output_loss: 0.2737 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5250 - val_loss: 0.7702 - val_y1_output_loss: 0.1951 - val_y2_output_loss: 0.5549 - val_y1_output_root_mean_squared_error: 0.4481 - val_y2_output_root_mean_squared_error: 0.7546
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4033 - y1_output_loss: 0.1213 - y2_output_loss: 0.2824 - y1_output_root_mean_squared_error: 0.3477 - y2_output_root_mean_squared_error: 0.5314 - val_loss: 3.1298 - val_y1_output_loss: 0.9859 - val_y2_output_loss: 2.0978 - val_y1_output_root_mean_squared_error: 1.0038 - val_y2_output_root_mean_squared_error: 1.4568
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4823 - y1_output_loss: 0.1498 - y2_output_loss: 0.3329 - y1_output_root_mean_squared_error: 0.3871 - y2_output_root_mean_squared_error: 0.5766 - val_loss: 0.8292 - val_y1_output_loss: 0.1607 - val_y2_output_loss: 0.6468 - val_y1_output_root_mean_squared_error: 0.4018 - val_y2_output_root_mean_squared_error: 0.8172
# Epoch 492/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3899 - y1_output_loss: 0.1190 - y2_output_loss: 0.2695 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5205 - val_loss: 0.7473 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.5385 - val_y1_output_root_mean_squared_error: 0.4396 - val_y2_output_root_mean_squared_error: 0.7443
# Epoch 493/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3362 - y1_output_loss: 0.1160 - y2_output_loss: 0.2191 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.4699 - val_loss: 0.8775 - val_y1_output_loss: 0.2481 - val_y2_output_loss: 0.6120 - val_y1_output_root_mean_squared_error: 0.4947 - val_y2_output_root_mean_squared_error: 0.7955
# Epoch 494/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3628 - y1_output_loss: 0.1156 - y2_output_loss: 0.2619 - y1_output_root_mean_squared_error: 0.3391 - y2_output_root_mean_squared_error: 0.4979 - val_loss: 4.2856 - val_y1_output_loss: 0.5149 - val_y2_output_loss: 3.8273 - val_y1_output_root_mean_squared_error: 0.7142 - val_y2_output_root_mean_squared_error: 1.9431
# Epoch 495/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4629 - y1_output_loss: 0.1227 - y2_output_loss: 0.3365 - y1_output_root_mean_squared_error: 0.3519 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 0.7942 - val_y1_output_loss: 0.1799 - val_y2_output_loss: 0.5956 - val_y1_output_root_mean_squared_error: 0.4220 - val_y2_output_root_mean_squared_error: 0.7849
# Epoch 496/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4518 - y1_output_loss: 0.1339 - y2_output_loss: 0.3531 - y1_output_root_mean_squared_error: 0.3541 - y2_output_root_mean_squared_error: 0.5713 - val_loss: 5.0269 - val_y1_output_loss: 1.8189 - val_y2_output_loss: 3.1153 - val_y1_output_root_mean_squared_error: 1.3666 - val_y2_output_root_mean_squared_error: 1.7775
# Epoch 497/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.8469 - y1_output_loss: 0.3229 - y2_output_loss: 0.5175 - y1_output_root_mean_squared_error: 0.5703 - y2_output_root_mean_squared_error: 0.7222 - val_loss: 1.2315 - val_y1_output_loss: 0.3163 - val_y2_output_loss: 0.8789 - val_y1_output_root_mean_squared_error: 0.5655 - val_y2_output_root_mean_squared_error: 0.9548
# Epoch 498/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3647 - y1_output_loss: 0.1322 - y2_output_loss: 0.2324 - y1_output_root_mean_squared_error: 0.3638 - y2_output_root_mean_squared_error: 0.4820 - val_loss: 1.0944 - val_y1_output_loss: 0.2542 - val_y2_output_loss: 0.8347 - val_y1_output_root_mean_squared_error: 0.5090 - val_y2_output_root_mean_squared_error: 0.9139
# Epoch 499/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3907 - y1_output_loss: 0.1187 - y2_output_loss: 0.2689 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.5208 - val_loss: 0.9999 - val_y1_output_loss: 0.2196 - val_y2_output_loss: 0.7512 - val_y1_output_root_mean_squared_error: 0.4704 - val_y2_output_root_mean_squared_error: 0.8824
# Epoch 500/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3035 - y1_output_loss: 0.0924 - y2_output_loss: 0.2104 - y1_output_root_mean_squared_error: 0.3034 - y2_output_root_mean_squared_error: 0.4599 - val_loss: 0.8118 - val_y1_output_loss: 0.1780 - val_y2_output_loss: 0.6125 - val_y1_output_root_mean_squared_error: 0.4225 - val_y2_output_root_mean_squared_error: 0.7958

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 0.8118 - y1_output_loss: 0.1811 - y2_output_loss: 0.6250 - y1_output_root_mean_squared_error: 0.4225 - y2_output_root_mean_squared_error: 0.7958
# Loss = 0.8117603605443781, Y1_loss = 0.1810804307460785, Y1_mse = 0.42250296473503113, Y2_loss = 0.625038206577301, Y2_mse = 0.795771062374115

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
